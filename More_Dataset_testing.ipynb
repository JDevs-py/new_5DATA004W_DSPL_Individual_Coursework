# %% [markdown]
# <a href="https://colab.research.google.com/github/JDevs-py/new_5DATA004W_DSPL_Individual_Coursework/blob/main/More_Dataset_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Files were uploaded from local storage onto the session storage before being loaded

# %%
import pandas as pd # Importing necessary library
df_region = pd.read_excel('/content/1b_Residence_by_Region_England.xlsx', index_col = 0) # Loading dataset and removing index
df_region_transposed = df_region.transpose() # Transposing dataset
df_region_transposed # Displaying transposed version
# Out:
# Year  North East  North West  East Midlands  London  South East  South West
# 2002       18075       19281          19513   25235       22880       19308
# 2003       18349       20031          20245   26201       23797       20120
# 2004       19311       20895          20935   27046       24700       21000
# 2005       20132       21923          21950   28177       25224       21667
# 2006       20431       22052          22187   28671       25924       22255
# 2007       21026       22833          22544   29841       26666       22951
# 2008       21872       23864          23724   31097       27876       23968
# 2009       22847       24011          24549   31941       28657       24523
# 2010       23184       24291          24453   32003       28822       24474
# 2011       23204       24166          24337   31852       29286       24791
# 2012       23769       24646          24995   32509       29461       25036
# ...

# %%
df_region_transposed.to_csv('1b_median_residence_transposed.csv')
# Save the transposed residence by region as a csv file

# %%
df_eastmid = pd.read_excel('/content/East_Midlands_Residence_Districts.xlsx', index_col = 0) # Load the East Midlands dataset
# for residence earnings
df_eastmid_transposed = df_eastmid.transpose() # Transpose dataset
df_eastmid_transposed # Display transposed version
# Out:
# Year  Derby  Leicester  Rutland  Nottingham  Amber Valley  Bolsover  \
# 2002  20786      16186    19332       17611         19103     16327
# 2003  21453      17350    23227       17873         19766     17568
# 2004  22081      17720    21095       19142         20574     19632
# 2005  23769      18900    21586       20403         22899     19643
# 2006  23350      19130    21998       21025         22450     20969
# 2007  21372      20232    23975       21793         21961     23017
# 2008  24793      20091    24977       20419         24291     21816
# 2009  26529      20845    26339       22681         23965     23654
# 2010  26413      20932    25061       22098         24685     23548
# 2011  26274      21323    25925       23000         24719     21716
# 2012  27211      20777    24336       22645         25259     25786
# 2013  26481      21785    24793       22308         25349     23216
# 2014  27442      22135    25416       22016         25660     23757
# ...

# %%
df_median_eastmid_houseprice = pd.read_excel('/content/East_Midlands_Median_house_price_District.xlsx', index_col = 0) # Loading the east midlands data
# for median house price
df_median_eastmid_houseprice_transposed = df_median_eastmid_houseprice.transpose() # Transposes the dataset
df_median_eastmid_houseprice_transposed # Displays the dataset
# Out:
# Year   Derby  Leicester  Rutland  Nottingham  Amber Valley  Bolsover  \
# 2002   62950      64500   125750       59950         66000     41350
# 2003   79000      83000   154950       79950         84000     59950
# 2004  100500     105000   179950       93000        103000     78775
# 2005  115000     115000   195000       99000        115950     91000
# 2006  119995     118000   205500      105000        123000     97000
# 2007  125000     124900   210000      106000        130000    106995
# 2008  125000     125000   225000      103000        135000    110000
# 2009  120000     118000   202500       98000        125000     97000
# 2010  124500     120000   220000      100000        131000    102000
# 2011  119000     120000   209250       95000        126000     92500
# 2012  121000     119975   211350       96000        125000     93500
# 2013  125000     121000   217000       95500        127750     92500
# 2014  130000     125000   225000      105000        131000    102000
# ...

# %%
df_median_eastmid_houseprice_transposed.to_csv('5a_eastmid_median_houseprice_transposed.csv')
df_eastmid_transposed.to_csv('5b_eastmid_median_residence_transposed.csv')
# Save the transposed East midlands datasets as csv files

# %%
df_ldn = pd.read_excel('/content/London_Residence_Districts.xlsx', index_col = 0) # Load the London dataset and remove index
# for residence earnings
df_ldn_transposed = df_ldn.transpose() # Transpose it
df_ldn_transposed # Display the dataset
# Out:
# Year  Barking and Dagenham  Barnet  Bexley  Hounslow  Islington  \
# 2002                 22854   26415   23757     23994      26968
# 2003                 21878   26513   25298     24379      28166
# 2004                 21690   28787   26333     24287      28838
# 2005                 22794   29567   27024     26179      29997
# 2006                 25197   29061   28001     25600      31996
# 2007                 25519   29512   28911     26453      32589
# 2008                 25620   31440   30859     27714      32740
# 2009                 28624   33041   31018     28121      34026
# 2010                 26498   32674   31262     29053      33971
# 2011                 25915   32490   32041     29236      36241
# 2012                 26976   32331   32332     30000      38075
# 2013                 28403   32964   32930     30037      35446
# 2014                 27173   32138   32362     30099      36833
# 2015                 28511   33072   31987     29323      35442
# ...

# %%
df_median_ldn_houseprice = pd.read_excel('/content/London_Median_house_price_District.xlsx', index_col = 0) # Load the London dataset
# for median houseprice
df_median_ldn_houseprice_transposed = df_median_ldn_houseprice.transpose() # Transpose the dataset
df_median_ldn_houseprice_transposed # Display the dataset
# Out:
# Year  Barking and Dagenham  Barnet  Bexley  Hounslow  Islington  \
# 2002                106000  195000  130000    165000     231000
# 2003                136000  225000  157000    186500     240000
# 2004                155000  247500  172000    207000     246500
# 2005                164000  250000  182000    220000     265000
# 2006                165000  265000  190000    232000     289950
# 2007                180000  290000  208000    248000     335000
# 2008                191175  295000  215000    250000     350000
# 2009                165000  289950  195000    240000     342000
# 2010                165000  325000  209995    250000     365000
# 2011                170000  330000  218000    250000     399950
# 2012                170000  345000  215000    250000     420000
# 2013                177500  360000  225000    275000     440000
# 2014                205250  400000  249995    305000     525000
# 2015                235000  440000  280000    335000     580000
# ...

# %%
df_median_ldn_houseprice_transposed.to_csv('5a_ldn_median_houseprice_transposed.csv')
df_ldn_transposed.to_csv('5b_ldn_median_residence_transposed.csv')
# Save the transposed London datasets as csv files

# %%
df_northeast = pd.read_excel('/content/North_East_Residence_Districts.xlsx', index_col = 0) # Loads the north east data
# for the residence earnings
df_northeast_transposed = df_northeast.transpose() # transpose the dataset
df_northeast_transposed  # Displays transposed datasets
# Out:
# Year  Hartlepool  Middlesbrough  Redcar and Cleveland  Stockton-on-Tees  \
# 2002       18535          16807                 19781             19493
# 2003       18192          17345                 17688             19866
# 2004       19536          17357                 19929             22007
# 2005       20986          18418                 21391             23066
# 2006       20797          19157                 20324             22423
# 2007       21613          20006                 22268             23569
# 2008       23392          21831                 21017             24315
# 2009       25095          21264                 23111             25072
# 2010       23663          21260                 21529             24472
# 2011       24286          20572                 23607             25240
# 2012       25757          22724                 22154             24677
# 2013       24198          21708                 24344             26595
# ...

# %%
df_northeast_median_houseprice = pd.read_excel('/content/North_East_Median_house_price_District.xlsx', index_col = 0) # Loads northeast data
# for median house price
df_northeast_median_houseprice_transposed = df_northeast_median_houseprice.transpose() # transpose the dataset
df_northeast_median_houseprice_transposed # display transposed version
# Out:
# Year  Hartlepool  Middlesbrough  Redcar and Cleveland  Stockton-on-Tees  \
# 2002       43950          45500                 51000             59000
# 2003       45000          45000                 64495             75000
# 2004       50000          60000                 82000             95000
# 2005       57500          70000                 95000            105000
# 2006       82000          92375                110000            119950
# 2007       97500         102000                120000            128100
# 2008      102000          95000                117500            124950
# 2009       90000         102000                113750            122000
# 2010      100000         104950                117500            126500
# 2011       98000          93000                110000            122500
# 2012       95000          99000                112250            123500
# 2013      109000         102000                112000            125000
# ...

# %%
df_northeast_median_houseprice_transposed.to_csv('5a_northeast_median_houseprice_transposed.csv')
df_northeast_transposed.to_csv('5b_northeast_median_residence_transposed.csv')
# Save the North east datasets as csv files

# %% [markdown]
# Previous steps are repeated throughout the rest of the script

# %%
df_northwest = pd.read_excel('/content/North_West_Residence_Districts.xlsx', index_col = 0)
df_northwest_transposed = df_northwest.transpose()
df_northwest_transposed
# Out:
# Year  Halton  Warrington  Blackburn with Darwen  Blackpool  Burnley  Chorley  \
# 2002   18908       19787                  18037      15669    18280    19974
# 2003   19032       21617                  18626      17240    19450    20671
# 2004   20433       22157                  20349      17121    18708    20273
# 2005   20011       23345                  20867      18134    20748    22025
# 2006   19740       25794                  21010      18261    21017    21887
# 2007   21946       24463                  21752      19461    19683    22595
# 2008   22462       26778                  20823      19003    22096    23518
# 2009   22140       26324                  23097      19384    20758    24417
# 2010   22849       26506                  22941      18597    21204    24154
# 2011   22781       26159                  20974      19254    21484    24591
# 2012   23776       26617                  21753      19294    22628    25723
# ...

# %%
df_northwest_median_houseprice = pd.read_excel('/content/North_West_Median_house_price_District.xlsx', index_col = 0)
df_northwest_median_houseprice_transposed = df_northwest_median_houseprice.transpose()
df_northwest_median_houseprice_transposed
# Out:
# Year  Halton  Warrington  Blackburn with Darwen  Blackpool  Burnley  Chorley  \
# 2002   56000       82500                  39000      54000    29950    68000
# 2003   69000       98000                  45000      67000    29950    84000
# 2004   85000      125000                  60000      86950    36000   110064
# 2005   99000      134000                  75000     100000    45000   125000
# 2006  110000      138000                  85000     112000    61000   133000
# 2007  115000      147000                  96000     117500    75000   137900
# 2008  116000      146000                 100000     117000    80000   145000
# 2009  113000      138000                  96500     102000    72500   132750
# 2010  120000      149995                  97000     105000    74700   137488
# 2011  110000      145000                  91500      98000    72000   132623
# 2012  109725      146000                  95000      95000    74000   130000
# ...

# %%
df_northwest_median_houseprice_transposed.to_csv('5a_northwest_median_houseprice_transposed.csv')
df_northwest_transposed.to_csv('5b_northwest_median_residence_transposed.csv')
# Save the north west dataset as a csv file

# %%
df_southeast = pd.read_excel('/content/South_East_Residence_Districts.xlsx', index_col = 0)
df_southeast_transposed = df_southeast.transpose()
df_southeast_transposed
# Out:
# Year  Reading  Slough  Windsor and Maidenhead  Wokingham  Milton Keynes  \
# 2002    23639   20452                   28769      29542          21029
# 2003    25306   20135                   31054      29264          22837
# 2004    25672   22229                   31528      28964          24222
# 2005    25262   22719                   33083      32112          23527
# 2006    24747   23405                   34686      33260          23966
# 2007    27280   24577                   33632      33379          25505
# 2008    29350   25380                   34918      35054          26140
# 2009    30525   26605                   35987      33753          26117
# 2010    29601   26408                   34779      35748          26643
# 2011    28354   26780                   37451      36456          28299
# 2012    31539   27635                   38927      36499          28134
# 2013    32162   28134                   37812      37035          29937
# ...

# %%
df_southeast_median_houseprice = pd.read_excel('/content/South_East_Median_house_price_District.xlsx', index_col = 0)
df_southeast_median_houseprice_transposed = df_southeast_median_houseprice.transpose()
df_southeast_median_houseprice_transposed
# Out:
# Year  Reading  Slough  Windsor and Maidenhead  Wokingham  Milton Keynes  \
# 2002   136000  124000                  210000     189950         105000
# 2003   155000  144950                  240000     214995         127000
# 2004   160875  160000                  249950     227000         145000
# 2005   170000  171500                  268500     240000         151500
# 2006   177250  176000                  275000     245000         158000
# 2007   199000  189950                  307500     272500         174000
# 2008   202000  197500                  320000     270000         175000
# 2009   180000  175000                  295000     249000         155000
# 2010   192500  183000                  320000     267500         168000
# 2011   190000  190000                  325000     275000         168000
# 2012   195000  192750                  322500     279950         174000
# 2013   205000  202000                  333000     282500         180000
# ...

# %%
df_southeast_median_houseprice_transposed.to_csv('5a_southeast_median_houseprice_transposed.csv')
df_southeast_transposed.to_csv('5b_southeast_median_residence_transposed.csv')
# Save the South east dataset as a csv file

# %%
df_southwest = pd.read_excel('/content/South_West_Residence_Districts.xlsx', index_col = 0)
df_southwest_transposed = df_southwest.transpose()
df_southwest_transposed
# Out:
# Year  Bath and North East Somerset  Bristol, City of  North Somerset  \
# 2002                         21601             19756           21329
# 2003                         22943             20538           22559
# 2004                         23118             21506           24353
# 2005                         22988             22064           25246
# 2006                         24754             22315           26040
# 2007                         24634             22899           26726
# 2008                         25651             23874           26832
# 2009                         24938             25147           27216
# 2010                         26248             25570           27695
# 2011                         25937             25235           28700
# 2012                         26864             25501           29037
# 2013                         29302             25910           29746
# 2014                         27953             26541           29893
# ...

# %%
df_southwest_median_houseprice = pd.read_excel('/content/South_West_Median_house_price_District.xlsx', index_col = 0)
df_southwest_median_houseprice_transposed = df_southwest_median_houseprice.transpose()
df_southwest_median_houseprice_transposed
# Out:
# Year  Bath and North East Somerset  Bristol, City of  North Somerset  \
# 2002                        139950            105000          107000
# 2003                        167500            128850          130000
# 2004                        186000            142000          150000
# 2005                        195000            150000          161725
# 2006                        204600            159000          169950
# 2007                        227000            174000          185000
# 2008                        225000            175000          189000
# 2009                        200000            160000          174950
# 2010                        229975            172500          188000
# 2011                        230000            172500          184975
# 2012                        232750            175000          183950
# 2013                        238500            176000          189000
# 2014                        245000            188000          200000
# ...

# %%
df_southwest_median_houseprice_transposed.to_csv('5a_southwest_median_houseprice_transposed.csv')
df_southwest_transposed.to_csv('5b_southwest_median_residence_transposed.csv')
# Save the south west dataset as a csv file
